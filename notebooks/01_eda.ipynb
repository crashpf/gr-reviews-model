# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\Studying\Machine-Learning\ML-projects\gr-reviews-model\data\raw\Sentiment-analysis.xlsx")

# %%
print(df.head(2))
# Out:
#                                                 text     label
# 0  Έρχομαι από galaxy 5 , δυστυχώς το galaxy 7 ει...  negative
# 1  Άνετα και πολύ όμορφα παπούτσια. Δεν μπορούσαν...  negative

# %%
df["text"][1]
# Out:
# 'Άνετα και πολύ όμορφα παπούτσια. Δεν μπορούσαν να βάλουν καλύτερης ποιότητας ύφασμα. Στο τρίτο μήνα άρχισαν να εμφανίζονται μικρά σκισιματα και στα δύο παπούτσια στο ύφασμα στο μπροστινό μέρος. Και τα είχα μόνο για έξω βόλτα τα απογεύματα. Όχι ασκήσεις και στην δουλειά. Απαράδεκτο για την Adidas.'

# %%
print(df["label"].value_counts())
# Out:
# label
# positive    84
# negative    79
# neutral     37
# Name: count, dtype: int64
